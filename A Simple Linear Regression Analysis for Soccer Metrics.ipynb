# %% [markdown]
# # IMPORTING THE NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## LOADING THE DATA

# %%
data = pd.read_csv("C:/Users/DENNIS/Desktop/SOCCER_DATA/FBREF DATA/2020_21  EPL SEASON SQUAD STANDARD STATS AS AT END OF SEASON.csv")
data.head()
# Out:
#          Squad  # Pl   Age  Poss  MP  Starts   Min  90s  Gls  Ast  ...  \
# 0      Arsenal    29  25.9  53.8  38     418  3420   38   53   38  ...
# 1  Aston Villa    24  25.2  48.1  38     418  3420   38   52   38  ...
# 2     Brighton    27  25.8  51.3  38     418  3420   38   39   24  ...
# 3      Burnley    25  28.3  41.7  38     418  3420   38   32   20  ...
# 4      Chelsea    27  26.0  61.4  38     418  3420   38   56   38  ...
#
#    G+A-PK/90    xG  npxG    xA  npxG+xA  Xg/90  xA/90  xG+xA/90  npxG/90  \
# 0       2.24  53.5  49.0  36.6     85.5   1.41   0.96      2.37     1.29
# 1       2.24  52.9  48.5  37.1     85.6   1.39   0.98      2.37     1.28
# 2       1.50  51.6  44.8  33.0     77.8   1.36   0.87      2.23     1.18
# 3       1.29  39.9  37.6  27.1     64.8   1.05   0.71      1.76     0.99
# 4       2.26  64.0  56.4  42.4     98.8   1.68   1.12      2.80     1.48
#
#    npxG+xA/90
# 0        2.25
# 1        2.25
# 2        2.05
# 3        1.70
# 4        2.60
#
# ...

# %% [markdown]
# ## QUICK DESCRIPTIVE ANALYSIS OF THE DATA

# %%
data.describe()
# Out:
#             # Pl       Age      Poss    MP  Starts     Min   90s        Gls  \
# count  20.000000  20.00000  20.00000  20.0    20.0    20.0  20.0  20.000000
# mean   26.600000  26.55000  50.02500  38.0   418.0  3420.0  38.0  49.300000
# std     2.161871   0.98221   7.98768   0.0     0.0     0.0   0.0  16.316282
# min    23.000000  25.20000  37.60000  38.0   418.0  3420.0  38.0  19.000000
# 25%    24.000000  25.97500  42.60000  38.0   418.0  3420.0  38.0  37.750000
# 50%    27.000000  26.35000  50.60000  38.0   418.0  3420.0  38.0  49.500000
# 75%    28.250000  26.87500  54.90000  38.0   418.0  3420.0  38.0  61.000000
# max    30.000000  29.10000  63.90000  38.0   418.0  3420.0  38.0  82.000000
#
#              Ast       G-PK  ...  G+A-PK/90         xG       npxG         xA  \
# count  20.000000  20.000000  ...  20.000000  20.000000  20.000000  20.000000
# mean   34.250000  44.200000  ...   2.064000  49.965000  45.240000  33.545000
# ...

# %% [markdown]
# ## CREATING A MULTI ANALYSIS GRID USING SEABORN

# %%
sns.pairplot(data[['Gls','Ast', 'xG', 'xA', 'Xg/90',"xA/90"]])

# %% [markdown]
# ## RELATING THE VARIOUS METRICS

# %%
abs(data['xG'].corr(data['xA'])) > data['Xg/90'].corr(data['xA/90'])
# Out:
# True

# %%
abs(data['Gls'].corr(data['Ast'])) > data['Xg/90'].corr(data['xA/90'])
# Out:
# True

# %%
abs(data['Gls'].corr(data['xA'])) > data['Xg/90'].corr(data['Ast'])
# Out:
# True
